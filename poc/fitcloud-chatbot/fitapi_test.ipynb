# %%
import streamlit as st
import requests

fitcloud_url = "https://aws-dev.fitcloud.co.kr"

# account 일자별 사용량
def ondemand_account_day(accountId: str, day_from: str, day_to: str):
  api_url = fitcloud_url + "/ondemand/account/day"
  data = {"from": day_from, "to": day_to, "accountId": accountId}
  cookie = {'JSESSIONID': "3F50D26AA5E1587357FD4B1EC5A1F4B1" }
  resp = requests.post(api_url, json=data, cookies=cookie)

  if resp.status_code == 200:
    json_data = resp.json()
    print("successful request!")
    print(json_data)

  else:
    print("error")

if __name__ == "__main__":
  ondemand_account_day(accountId="532805286864", day_from="20230901", day_to="20230930")
# Out:
# successful request!
# ...
